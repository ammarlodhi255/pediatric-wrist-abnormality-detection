# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/FYP_Work/Code/Faster_R-CNN
# %cd /content/drive/MyDrive/Faster_R-CNN
# %ls
# Out:
# /content/drive/.shortcut-targets-by-id/1klbe1Zh9vS5iLD78Z5WFbw68lrLIJGgf/Faster_R-CNN
# data/          eval.py             __init__.py  __pycache__/      torch_utils/
# data_configs/  inference.py        models/      requirements.txt  train.py
# datasets.py    inference_video.py  outputs/     Terminal.ipynb    utils/

# %%
import os

datasetpath = f'data/ppe/dataset'

# print(len(os.listdir(f"{datasetpath}/images/train")))
# print(len(os.listdir(f"{datasetpath}/labels/train")))
# print()

print(len(os.listdir(f"{datasetpath}/images/val")))
print(len(os.listdir(f"{datasetpath}/labels/val")))
print()

# print(len(os.listdir(f"{datasetpath}/images/test")))
# print(len(os.listdir(f"{datasetpath}/labels/test")))
# Out:
# 1
# 1

# %%
# !wandb login
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
# !python train.py --model fasterrcnn_resnet50_fpn --config data_configs/ppe.yaml --batch-size 16 --epochs 100 --project-name fasterrcnn_resnet50_fpn_ppe --no-mosaic --resume-training --weights outputs/training/fasterrcnn_resnet50_fpn_ppe/last_model.pth
# Out:
# Train Images Dir: data/ppe/dataset/images/train
# Train Labels Dir: data/ppe/dataset/labels/train
#
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Number of training samples: 15231
# Number of validation samples: 1
#
# Loading pretrained weights...
# Downloading: "https://download.pytorch.org/models/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth" to /root/.cache/torch/hub/checkpoints/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth
# 100% 160M/160M [00:00<00:00, 189MB/s]
# RESUMING TRAINING...
# Resuming from epoch 10...
# Loading previous batch wise loss list...
# ...

# %%
# !python inference.py --weights outputs/training/fasterrcnn_resnet50_fpn_v2_ppe/best_model.pth --input data/inference_data/ --threshold 0.5

# %%
# !pip install torchmetrics
# !python eval.py --config data_configs/ppe.yaml --weights outputs/training/fasterrcnn_resnet50_fpn_v2_ppe/best_model.pth --model fasterrcnn_resnet50_fpn_v2 --verbose --square-training --batch-size 4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 512.4/512.4 KB 25.4 MB/s eta 0:00:00
# ...
# Downloading: "https://download.pytorch.org/models/fasterrcnn_resnet50_fpn_v2_coco-dd69338a.pth" to /root/.cache/torch/hub/checkpoints/fasterrcnn_resnet50_fpn_v2_coco-dd69338a.pth
# 100% 167M/167M [00:03<00:00, 57.2MB/s]
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
#  37% 95/254 [58:58<1:38:50, 37.30s/it]
