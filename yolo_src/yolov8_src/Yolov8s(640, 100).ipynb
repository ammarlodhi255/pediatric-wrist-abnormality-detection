# %% [markdown]
# The split of dataset is avaliable on drive you can download with this link: https://drive.google.com/file/d/1ubdO0_j2cr7AKSxVKQlGh99VzfrnyKfe/view?usp=sharing

# %%
from google.colab import drive
drive.mount('/content/drive')

# !pip install unrar
# !unrar x '/content/drive/MyDrive/Yolov5 Formatted Data (with test).rar'
file = open('/content/dataset.yaml', 'w')
file.write('path: /content/Yolo Formatted Data (with test)\n')
file.write('train: images/train\n')
file.write('val: images/val\n')
file.write('test: images/test\n')
file.write('nc: 9\n')
file.write("names: ['boneanomaly','bonelesion','foreignbody','fracture','metal','periostealreaction','pronatorsign','softtissue','text']\n")
file.close()

# !pip install ultralytics
from ultralytics import YOLO
# %cd /content/drive/MyDrive/YOLOv8 (updated)
# Out:
# Streaming output truncated to the last 5000 lines.
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# ...

# %% [markdown]
# #YOLOv8s

# %% [markdown]
# ###Training

# %%
# model = YOLO('yolov8s.yaml')  #only used when you're start training from scract with zero epoch
model = YOLO('/content/drive/MyDrive/YOLOv8 (updated)/runs/detect/Yolov8s(640, 100, 16)/weights/last.pt')     #for resume
results = model.train(data="/content/dataset.yaml", imgsz=640, epochs=100, batch=16, resume=True, cache=False, pretrained=False, name='Yolov8s(640, 100, 16)', iou=0.5)
# Out:
# Ultralytics YOLOv8.0.49 🚀 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model = YOLO('runs/detect/Yolov8s(640, 100, 16)/weights/last.pt')
results = model.val(iou=0.5)
# Out:
# Ultralytics YOLOv8.0.51 🚀 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8s summary (fused): 168 layers, 11129067 parameters, 0 gradients, 28.5 GFLOPs
# ...
#   0%|          | 0.00/755k [00:00<?, ?B/s]
# val: Scanning /content/Yolo Formatted Data (with test)/labels/val... 4065 images, 1 backgrounds, 0 corrupt: 100%|██████████| 4065/4065 [00:19<00:00, 208.32it/s]
# val: New cache created: /content/Yolo Formatted Data (with test)/labels/val.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 255/255 [01:48<00:00,  2.35it/s]
#                    all       4065       9504      0.575      0.588      0.584      0.352
#            boneanomaly       4065         56      0.346      0.226      0.226     0.0596
#             bonelesion       4065          6          0          0    0.00599    0.00335
#               fracture       4065       3658       0.89      0.888      0.934       0.55
# ...

# %% [markdown]
# #Test Data

# %%
model = YOLO('runs/detect/Yolov8s(640, 100, 16)/weights/best.pt')
results = model.val(iou=0.5, split='test')
# Out:
# Ultralytics YOLOv8.0.51 🚀 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8s summary (fused): 168 layers, 11129067 parameters, 0 gradients, 28.5 GFLOPs
# val: Scanning /content/Yolo Formatted Data (with test)/labels/test... 1016 images, 0 backgrounds, 0 corrupt: 100%|██████████| 1016/1016 [00:05<00:00, 200.70it/s]
# val: New cache created: /content/Yolo Formatted Data (with test)/labels/test.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 64/64 [00:29<00:00,  2.17it/s]
#                    all       1016       2351      0.721      0.633      0.646      0.394
#            boneanomaly       1016         14       0.45      0.286      0.269       0.14
#             bonelesion       1016          2          1      0.812      0.995      0.597
#            foreignbody       1016          1          1          0          0          0
# ...

# %%
model = YOLO('runs/detect/Yolov8s(640, 100, 16)/weights/last.pt')
results = model.val(iou=0.5, split='test')
# Out:
# Ultralytics YOLOv8.0.51 🚀 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8s summary (fused): 168 layers, 11129067 parameters, 0 gradients, 28.5 GFLOPs
# val: Scanning /content/Yolo Formatted Data (with test)/labels/test.cache... 1016 images, 0 backgrounds, 0 corrupt: 100%|██████████| 1016/1016 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 64/64 [00:29<00:00,  2.18it/s]
#                    all       1016       2351       0.74      0.618      0.635      0.387
#            boneanomaly       1016         14      0.474      0.286      0.246      0.127
#             bonelesion       1016          2      0.878          1      0.995      0.572
#            foreignbody       1016          1          1          0          0          0
#               fracture       1016        903      0.905      0.883      0.935      0.557
# ...
